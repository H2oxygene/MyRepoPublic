# %%
from transformers import pipeline

prompt = "Explique-moi un LLM"
generator = pipeline("text-generation", model="Qwen/Qwen2.5-0.5B-Instruct")
result = generator(prompt, max_new_tokens=100)
print(result[0]["generated_text"])
